# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("heartdisease.csv")
df
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
#Handling column Name
df.columns=["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"]

# %%
df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     44    1   4      130  209   0        1     127     0       0     ?  ?
# 1     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3     66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4     66    1   3      120    0   0        1     120     0    -0.5     1  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 194   54    0   4      127  333   1        1     154     0       0     ?  ?
# 195   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 196   55    1   4      122  223   1        1     100     0       0     ?  ?
# 197   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 198   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    0
# 1      ?    2
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     44    1   4      130  209   0        1     127     0       0     ?  ?
# 1     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3     66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4     66    1   3      120    0   0        1     120     0    -0.5     1  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 194   54    0   4      127  333   1        1     154     0       0     ?  ?
# 195   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 196   55    1   4      122  223   1        1     100     0       0     ?  ?
# 197   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 198   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# ...

# %%
#Handling ? present in dataset.
df=df.replace("?","0")
df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     44    1   4      130  209   0        1     127     0       0     0  0
# 1     60    1   4      132  218   0        1     140     1     1.5     3  0
# 2     55    1   4      142  228   0        1     149     1     2.5     1  0
# 3     66    1   3      110  213   1        2      99     1     1.3     2  0
# 4     66    1   3      120    0   0        1     120     0    -0.5     1  0
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 194   54    0   4      127  333   1        1     154     0       0     0  0
# 195   62    1   1        0  139   0        1       0     0       0     0  0
# 196   55    1   4      122  223   1        1     100     0       0     0  0
# 197   58    1   4        0  385   1        2       0     0       0     0  0
# 198   62    1   2      120  254   0        2      93     1       0     0  0
#
#     thal  num
# 0      0    0
# 1      0    2
# ...

# %%
df.shape
# Out:
# (199, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age          int64
# sex          int64
# cp           int64
# trestbps    object
# chol        object
# fbs         object
# restecg      int64
# thalach     object
# exang       object
# oldpeak     object
# slope       object
# ca          object
# thal        object
# num          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  199 non-null    object
#  4   chol      199 non-null    object
#  5   fbs       199 non-null    object
#  6   restecg   199 non-null    int64
#  7   thalach   199 non-null    object
#  8   exang     199 non-null    object
#  9   oldpeak   199 non-null    object
#  10  slope     199 non-null    object
#  11  ca        199 non-null    object
#  12  thal      199 non-null    object
#  13  num       199 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 21.9+ KB

# %%
df.describe()
# Out:
#               age         sex          cp     restecg         num
# count  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513    0.733668    1.517588
# std      7.827080    0.171433    0.796928    0.684918    1.222038
# min     35.000000    0.000000    1.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000    1.000000    1.000000
# 75%     64.000000    1.000000    4.000000    1.000000    3.000000
# max     77.000000    1.000000    4.000000    2.000000    4.000000

# %% [markdown]
# Here we observe mean values and median ,median is greater than the mean so it is left side skew data is present
# Here we observe 75 percentile and maximum large difference only age factor remaining no difference is there

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %%
#Lets check the null values without using visualization
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2DC64D7C8>,
# ...
#       dtype=object)

# %%
df.plot(kind='box',subplots=True,layout=(2,6))
# Out:
# age           AxesSubplot(0.125,0.536818;0.110714x0.343182)
# sex        AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# cp         AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# restecg    AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# num        AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# dtype: object

# %%
sns.pairplot(df)

# %%
#Lets check the correlation matrix
df.corr()
# Out:
#               age       sex        cp   restecg       num
# age      1.000000  0.033837 -0.039809  0.001487  0.286630
# sex      0.033837  1.000000  0.037525  0.060305  0.147190
# cp      -0.039809  0.037525  1.000000  0.033617  0.167202
# restecg  0.001487  0.060305  0.033617  1.000000 -0.033597
# num      0.286630  0.147190  0.167202 -0.033597  1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='Blues',annot=True)

# %%
#Lets check the skewness of the dataset
df.skew()
#there is some skewness which needs to be treated ,by seeing we can say obly +ve skewness is signifiacnt and needs to be treated
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -0.742397
# chol       -0.461558
# fbs         0.672579
# restecg     0.396540
# thalach    -0.709355
# exang       0.111565
# oldpeak     0.838673
# slope       0.479716
# ca          0.000000
# thal        1.897022
# num         0.302681
# dtype: float64
